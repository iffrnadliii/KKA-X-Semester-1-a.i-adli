# %% [markdown]
# <a href="https://colab.research.google.com/github/iffrnadliii/KKA-X-Semester-1-a.i-adli/blob/main/Tipe_Variabel_Adli_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama : ahmad ifirrin adli
#
# kelas :X.2
#
# no.absen :02

# %% [markdown]
# #konsep dasar variabel

# %%
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %%
email_user = "shintahanafiaa.2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %%
#hanya boleh menggunakan huruf, angka, dan underscore
harga telur =15000
print(harga telur)
# Out:
#   File "/tmp/ipython-input-703277716.py", line 2
#     harga telur =15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
#tidak boleh diawali dengan angka
1_nama_siswa ="ahmad dhani"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-3338601468.py", line 2
#     1_nama_siswa ="ahmad dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#tidak boleh menggunakan kata kunci python
if = "handayani"
print(if)
# Out:
#   File "/tmp/ipython-input-245188923.py", line 2
#     if = "handayani"
#        ^
# SyntaxError: invalid syntax

# %%
If = "handayani"
print(If)
# Out:
# handayani

# %%
print = "Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2451231669.py in <cell line: 0>()
#       1 print = "Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
#sensitif terhadap penulisan kapital
USIA = 17
print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3015126514.py in <cell line: 0>()
#       1 #sensitif terhadap penulisan kapital
#       2 USIA = 17
# ----> 3 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "Fazel Wardana"

# %%
_ = "Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# #assignment

# %%
#single assignment
bb_fazel = 55
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#multiple assignment
bb_fazel, bb_dani =55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani = 55,60,70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2460095539.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani = 55,60,70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1, nama_siswa_2 ="deni", "doni"

print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel, bb_dani, bb_adli= 55,60
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3889902991.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli= 55,60
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assignment
bb_hasbi = bb_dani =60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# #cara penulisan operator pada python

# %%
#tanpa variabel
print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#operand disimpan ke variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6
print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#hasil operasi disimpan di variabel

# %% [markdown]
# jenis jenis tipe variabel

# %%
a = "faris"
print(a)
type(a)
# Out:
# faris
# str

# %%
b = 9.9
print(b)
type(b)
# Out:
# 9.9
# float

# %%
c = 0
print(c)
type(c)
# Out:
# 0
# int

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3822527092.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
f = "false"
print(f)
type(f)
# Out:
# false
# str

# %%
g = 9,2
print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("rendra")
# Out:
# str

# %%
type(-9.2)
# Out:
# float

# %% [markdown]
# mengubah bentuk variabel

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
b = bool(2)
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# #operator perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %% [markdown]
# #operator logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0==1 and 1!=1))
# Out:
# True

# %%
print(not(5<10 or 5<=10))
# Out:
# False
